# %%
import torch

# %% [markdown]
# Esto sería como un cubo en el cual x en su "cara" x.grad sería

# %%
x = torch.tensor([2.0], requires_grad = True)
y = 3*x**2 + 3*x + 1
y = y.backward()

print(x.grad)
# Out:
# tensor([15.])
